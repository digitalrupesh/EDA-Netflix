# %% [markdown]
# ## Netflix EDA
#
# Performing Explotary data Analysis to Understand the dataset

# %% [markdown]
# ### Tasks
#
# *   Understand the dataset,types and Missing Values
# *   Clean the dataset and handle the missing values
# *   Perform data visualization
# *   Create Final Summary report

# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading our dataset
df=pd.read_csv("/content/netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df[df.isnull().any(axis=1)].head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'].isnull()
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Name: director, Length: 8807, dtype: bool

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df[['type']].value_counts().plot.barh()

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_added'].dtype
# Out:
# dtype('O')

# %%
#Convert the data type from object to datatime64
df['date_added']=pd.to_datetime(df['date_added'])

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %% [markdown]
# ### Handling Missing Values
# rating,cast,country and director have the null filled with 'Unavailable'

# %%
df.fillna({'rating':'Unavailable','cast':'Unavailable','country':'Unavailable','director':'Unavailable'},inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df['date_added']
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
df.sort_values(by='date_added',ascending=False)
# Out:
#      show_id     type                                title  \
# 0         s1    Movie                 Dick Johnson Is Dead
# 6         s7    Movie     My Little Pony: A New Generation
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 9        s10    Movie                         The Starling
# 8         s9  TV Show        The Great British Baking Show
# ...      ...      ...                                  ...
# 7196   s7197  TV Show                             Kikoriki
# 7254   s7255  TV Show                  La Familia P. Luche
# 7406   s7407  TV Show                                Maron
# 7847   s7848  TV Show                         Red vs. Blue
# 8182   s8183  TV Show         The Adventures of Figaro Pho
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 10                      Unavailable
# 9                    Theodore Melfi
# 8                   Andy Devonshire
# ...

# %%
df2=df['date_added']

# %%
df2
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
df2.sort_values(ascending=True)
# Out:
# 5957   2008-01-01
# 6611   2008-02-04
# 5956   2009-05-05
# 5955   2009-11-18
# 7370   2010-11-01
#           ...
# 7196          NaT
# 7254          NaT
# 7406          NaT
# 7847          NaT
# 8182          NaT
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
df2.max()
# Out:
# Timestamp('2021-09-25 00:00:00')

# %%
df[df.date_added.isnull()] # at which row null value is their
# Out:
#      show_id     type                                        title  \
# 6066   s6067  TV Show  A Young Doctor's Notebook and Other Stories
# 6174   s6175  TV Show              Anthony Bourdain: Parts Unknown
# 6795   s6796  TV Show                                      Frasier
# 6806   s6807  TV Show                                      Friends
# 6901   s6902  TV Show                              Gunslinger Girl
# 7196   s7197  TV Show                                     Kikoriki
# 7254   s7255  TV Show                          La Familia P. Luche
# 7406   s7407  TV Show                                        Maron
# 7847   s7848  TV Show                                 Red vs. Blue
# 8182   s8183  TV Show                 The Adventures of Figaro Pho
#
#          director                                               cast  \
# 6066  Unavailable  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6174  Unavailable                                   Anthony Bourdain
# ...

# %%
most_recent_date=df['date_added'].max()
df.fillna({'date_added':most_recent_date},inplace=True)

# %%
df.isnull().sum() # proof that thir is not a null value
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
df[df.date_added.isnull()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## **# Additional data Cleaning**
#
# # Duration data input error
#
# The missing duration are all movies by Louis C.K normally we would likely fill the duration with the mean duration of the movies from the table .In this case it appears that the actual duration was input into the rating column,so one solution is to move the rating data in to duration and make the rating imformation 'unavailable' like the other nulls.

# %%
df[df.duration.isnull()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
df[df.director=='Louis C.K.']
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
df.loc[df['director']=='Louis C.K.','duration']
# Out:
# 5541    NaN
# 5794    NaN
# 5813    NaN
# Name: duration, dtype: object

# %%
#loc helps us easily accesing the columns by names
df.loc[df['director']=='Louis C.K.','duration']=df['rating']
df[df.director=='Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min   74 min
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min   84 min
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min   66 min
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
df[df.director=='Louis C.K.']
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min   74 min
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min   84 min
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min   66 min
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
df.loc[df['director']=='Louis C.K.','rating']='Unavailable'
df[df.director=='Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year       rating  \
# 5541  Louis C.K.  United States 2017-04-04          2017  Unavailable
# 5794  Louis C.K.  United States 2016-09-16          2010  Unavailable
# 5813  Louis C.K.  United States 2016-08-15          2015  Unavailable
#
#      duration listed_in                                        description
# 5541   74 min    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794   84 min    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813   66 min    Movies  The comic puts his trademark hilarious/thought...

# %% [markdown]
# # **Visualizations**
#
# Let's take a look at types of show that has been watched on netflix

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water      Unavailable
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans      Unavailable
# 4         s5  TV Show           Kota Factory      Unavailable
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb      Unavailable
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           Unavailable  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df.type.value_counts().plot.barh()
plt.xlabel("numbers")
plt.ylabel("show types")
plt.title("Types of shows most watched on Netflix")
# Out:
# Text(0.5, 1.0, 'Types of shows most watched on Netflix')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water      Unavailable
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans      Unavailable
# 4         s5  TV Show           Kota Factory      Unavailable
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb      Unavailable
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           Unavailable  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['country'].value_counts().head(10)
# Out:
# United States     2818
# India              972
# Unavailable        831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: country, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='country',order=df['country'].value_counts().index[0:10],data=df)
plt.title('Top 10 Country wise content on netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 Country wise content on netflix')

# %%
movie_countries=df[df['type']=='Movie']
tv_show_countries=df[df['type']=='TV Show']

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='country',order=df['country'].value_counts().index[0:10],data=movie_countries)
plt.title('Top 10 countries producing Movies in Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 countries producing Movies in Netflix')

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='country',order=df['country'].value_counts().index[0:10],data=tv_show_countries)
plt.title('Top 10 countries producing Tv_show in Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 countries producing Tv_show in Netflix')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water      Unavailable
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans      Unavailable
# 4         s5  TV Show           Kota Factory      Unavailable
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb      Unavailable
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           Unavailable  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
movies_rating=df['rating']

# %%
movies_rating
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
df['rating'].value_counts().plot.bar()

# %%
sns.countplot(y='rating',order=df['rating'].value_counts().index[0:10],data=df)
plt.title('Ratings of shows on netflix')
# Out:
# Text(0.5, 1.0, 'Ratings of shows on netflix')

# %% [markdown]
# Most of the shows has TV-MA and TV-14 ratings

# %%
df.release_year.value_counts()[0:20]
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# Name: release_year, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='release_year',order=df['release_year'].value_counts().index[0:20],data=df)

# %%
# Popular Genere Analysis

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water      Unavailable
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans      Unavailable
# 4         s5  TV Show           Kota Factory      Unavailable
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb      Unavailable
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           Unavailable  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['listed_in'].value_counts()[0:20]
# Out:
# Dramas, International Movies                         362
# Documentaries                                        359
# Stand-Up Comedy                                      334
# Comedies, Dramas, International Movies               274
# Dramas, Independent Movies, International Movies     252
# Kids' TV                                             220
# Children & Family Movies                             215
# Children & Family Movies, Comedies                   201
# Documentaries, International Movies                  186
# Dramas, International Movies, Romantic Movies        180
# Comedies, International Movies                       176
# Comedies, International Movies, Romantic Movies      152
# Dramas                                               138
# Dramas, International Movies, Thrillers              134
# Action & Adventure, Dramas, International Movies     132
# Action & Adventure                                   128
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='listed_in',order=df['listed_in'].value_counts().index[0:20],data=df)
plt.title('Popular Genere Analysis')
plt.show()

# %%
# Dramas ,International Movies has the highest Popular Genere on Netflix

# %%
df['listed_in'].value_counts()
# Out:
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: listed_in, Length: 514, dtype: int64

# %%
# we are now checking which country produce more Stand-Up Comedy

# %%
df[df['listed_in']=='Stand-Up Comedy']
# Out:
#      show_id   type                            title                 director  \
# 278     s279  Movie      Lokillo: Nothing's the Same           Julián Gaviria
# 359     s360  Movie     The Original Kings of Comedy                Spike Lee
# 475     s476  Movie                     The Stand-Up           Daniel Růžička
# 484     s485  Movie     Lee Su-geun: The Sense Coach            Kim Joo-hyung
# 766     s767  Movie          Alan Saldaña: Locked Up                Alex Díaz
# ...      ...    ...                              ...                      ...
# 7179   s7180  Movie       Kevin Hart: Let Me Explain  Leslie Small, Tim Story
# 7180   s7181  Movie      Kevin Hart: Seriously Funny          Shannon Hartman
# 7411   s7412  Movie  Martin Lawrence Live: Runteldat              David Raynr
# 7560   s7561  Movie     Natalia Valdebenito: Gritona      Natalia Valdebenito
# 7909   s7910  Movie        Russell Peters: Notorious               Dave Higby
#
# ...

# %%
stand_up_comedy=df[df['listed_in']=='Stand-Up Comedy']

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='country',order=df['country'].value_counts().index[0:20],data=stand_up_comedy)
plt.title('Popular Genere Analysis country wise')
# Out:
# Text(0.5, 1.0, 'Popular Genere Analysis country wise')

# %% [markdown]
# # **Summary,**
# So far we had perform lots of operatins over the dataset to dig out some very useful information from it. If ,we have to conclude the
# dataset in few line ,than we can say that
#
# 1) Netflix has more Movies than TV shows
# 2) Most number of Movies and TV Shows are produced by united states ,followed by India produced the second most number of movies on Netflix
# 3) Most of the content on Netflix (Movies and Tv shows Combined is for Mature Audience
# 4) 2018 is the year in which Netflix released alot more content as compared to other years.
# 5) International Movies and Dramas are the most popular Genres on Netflix

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water      Unavailable
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans      Unavailable
# 4         s5  TV Show           Kota Factory      Unavailable
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb      Unavailable
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           Unavailable  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['director'].value_counts()[0:20]
# Out:
# Unavailable               2634
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Jay Chapman                 12
# Youssef Chahine             12
# Martin Scorsese             12
# Steven Spielberg            11
# Don Michael Paul            10
# David Dhawan                 9
# Yılmaz Erdoğan               8
# Quentin Tarantino            8
# Lance Bangs                  8
# Shannon Hartman              8
# Troy Miller                  8
# Kunle Afolayan               8
# Johnnie To                   8
# Name: director, dtype: int64
